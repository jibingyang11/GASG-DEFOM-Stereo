# %%
import os
from PIL import Image

# %%
os.listdir()
# Out:
# ['depth0.png',
#  'depth1.png',
#  'depth10.png',
#  'depth100.png',
#  'depth1000.png',
#  'depth1001.png',
#  'depth1002.png',
#  'depth1003.png',
#  'depth1004.png',
#  'depth1005.png',
#  'depth1006.png',
#  'depth1007.png',
#  'depth1008.png',
#  'depth1009.png',
#  'depth101.png',
#  'depth1010.png',
#  'depth1011.png',
#  'depth1012.png',
#  'depth1013.png',
#  'depth1014.png',
#  'depth1015.png',
#  'depth1016.png',
#  'depth1017.png',
#  'depth1018.png',
#  'depth1019.png',
#  'depth102.png',
#  'depth1020.png',
#  'depth1021.png',
#  'depth1022.png',
#  'depth1023.png',
#  'depth1024.png',
#  'depth1025.png',
#  'depth1026.png',
#  'depth1027.png',
#  'depth1028.png',
#  'depth1029.png',
#  'depth103.png',
#  'depth1030.png',
#  'depth1031.png',
#  'depth1032.png',
#  'depth1033.png',
#  'depth1034.png',
#  'depth1035.png',
#  'depth1036.png',
#  'depth1037.png',
#  'depth1038.png',
#  'depth1039.png',
#  'depth104.png',
#  'depth1040.png',
#  'depth1041.png',
# ...

# %%
os.chdir('depth_left_truth')

# %%
for i,name in enumerate(os.listdir()):
    os.rename(name,f"depth{i}.png")
